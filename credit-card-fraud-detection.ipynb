# %%
# File location and type

# kaggle dataset --- https://www.kaggle.com/datasets/dhanushnarayananr/credit-card-fraud

file_location = "/FileStore/tables/card_data.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

df.repartition(4)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distance_from_home</th><th>distance_from_last_transaction</th><th>ratio_to_median_purchase_price</th><th>repeat_retailer</th><th>used_chip</th><th>used_pin_number</th><th>online_order</th><th>fraud</th></tr></thead><tbody><tr><td>57.87785658389723</td><td>0.3111400080477545</td><td>1.9459399775518593</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>10.829942699255545</td><td>0.17559150228166587</td><td>1.2942188106198573</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>5.091079490616996</td><td>0.8051525945853258</td><td>0.42771456119427587</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>2.2475643282963613</td><td>5.60004354707232</td><td>0.36266257805709584</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>44.19093600261837</td><td>0.5664862680583477</td><td>2.2227672978404707</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>5.586407674186407</td><td>13.261073268058121</td><td>0.06476846537046335</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>3.7240191247148107</td><td>0.9568379284821842</td><td>0.27846494490815554</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>4.8482465722805665</td><td>0.3207354272228163</td><td>1.2730495235601782</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>0.8766322564943629</td><td>2.5036089266921437</td><td>1.5169993152858177</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>8.83904670372637</td><td>2.9705122760243827</td><td>2.36168254706846</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>14.263529735069081</td><td>0.1587580860346303</td><td>1.1361019405394772</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>13.592367567909633</td><td>0.240539812984415</td><td>1.3703298614332031</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>765.2825592612469</td><td>0.3715619621963146</td><td>0.5512447476281009</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.131955665990563</td><td>56.3724005365082</td><td>6.358667321630612</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>13.95597236704443</td><td>0.27152152834856924</td><td>2.798901124938246</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>179.6651476857078</td><td>0.12091963755751828</td><td>0.5356404825310114</td><td>1.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>0.0</td></tr><tr><td>114.51978939161216</td><td>0.7070032526577117</td><td>0.516989925221995</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</
td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>8.83904670372637</td><td>2.9705122760243827</td><td>2.36168254706846</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>14.263529735069081</td><td>0.1587580860346303</td><td>1.1361019405394772</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>13.592367567909633</td><td>0.240539812984415</td><td>1.3703298614332031</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>765.2825592612469</td><td>0.3715619621963146</td><td>0.5512447476281009</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.131955665990563</td><td>56.3724005365082</td><td>6.358667321630612</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>13.95597236704443</td><td>0.27152152834856924</td><td>2.798901124938246</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>179.6651476857078</td><td>0.12091963755751828</td><td>0.5356404825310114</td><td>1.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>0.0</td></tr><tr><td>114.51978939161216</td><td>0.7070032526577117</td><td>0.516989925221995</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>3.5896485976213444</td><td>6.247457541963805</td><td>1.8464505265933646</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>11.085152484057602</td><td>34.66135141778853</td><td>2.530758449146248</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>6.194670766326057</td><td>1.142014235500891</td><td>0.3072166087549278</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>78.62324228597946</td><td>1.409245200233365</td><td>1.8380164275927833</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>3.9222119601658165</td><td>4.822091480482492</td><td>0.7037704483696168</td><td>1.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>1.6950504410379064</td><td>0.06920087623687993</td><td>0.18528617072490697</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>8.084177482766684</td><td>0.13820280642370242</td><td>0.3786612352998621</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>3.8030573513256023</td><td>67.24108052618409</td><td>1.872949614304464 ...

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "card_data_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)

# %%
#No of rows and columns
print(df.count(),len(df.columns))
# Out:
# 1000000 8

# %%
#No of null values in each column
from pyspark.sql.functions import col,isnan, when, count

df.select([count(when(isnan(c) | col(c).isNull(),c)).alias(c) for c in df.columns]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distance_from_home</th><th>distance_from_last_transaction</th><th>ratio_to_median_purchase_price</th><th>repeat_retailer</th><th>used_chip</th><th>used_pin_number</th><th>online_order</th><th>fraud</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
#describing numerical columns
pd = df.toPandas()
pd.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>distance_from_home</th>
#       <th>distance_from_last_transaction</th>
#       <th>ratio_to_median_purchase_price</th>
#       <th>repeat_retailer</th>
#       <th>used_chip</th>
#       <th>used_pin_number</th>
#       <th>online_order</th>
#       <th>fraud</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>1000000</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>78.80067845695436</td>
#       <td>8.838484043974422</td>
#       <td>0.2915701762061419</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>881536</td>
#       <td>649601</td>
#       <td>899392</td>
#       <td>650552</td>
#       <td>912597</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#rename fraud column name to label
df = df.withColumnRenamed("fraud","label")

# %%
#No of fraudulent and non-fradulent records
df.groupBy("label").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>count</th></tr></thead><tbody><tr><td>1.0</td><td>87403</td></tr><tr><td>0.0</td><td>912597</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import expr

fraud_df = df.filter(expr("label = 1"))
print("Fraud Count --- " + str(fraud_df.count()))
# Out:
# Fraud Count --- 87403

# %%
no_fraud_df = df.filter(expr("label = 0"))
print("Not Fraud Count --- " + str(no_fraud_df.count()))
# Out:
# Not Fraud Count --- 912597

# %%
# sampling unbalanced data to balanced data by selecting 60k records from each fraud and not fraud dataframes

#For fraudulent data, sampling 
col_names = df.columns
fraud_sample_list = fraud_df.sample(False,0.8,2321).take(60000)
fraud_sample_df = spark.createDataFrame(fraud_sample_list, col_names)
fraud_sample_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distance_from_home</th><th>distance_from_last_transaction</th><th>ratio_to_median_purchase_price</th><th>repeat_retailer</th><th>used_chip</th><th>used_pin_number</th><th>online_order</th><th>label</th></tr></thead><tbody><tr><td>15.694985541059943</td><td>175.98918151972342</td><td>0.8556228290724207</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>26.711462023719893</td><td>1.5520081259491354</td><td>4.603600688206188</td><td>1.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>10.664473716016785</td><td>1.5657690862016613</td><td>4.886520843107555</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>2.530145018135443</td><td>3.6897810904940105</td><td>8.297406866219774</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>21.12611616077098</td><td>0.27198739643980063</td><td>6.081770719263626</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>9.598401340573979</td><td>0.4545563461632137</td><td>6.084828700634962</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>22.545587575167414</td><td>0.35393925466184956</td><td>4.0954422060767035</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>335.1893199927121</td><td>1.1141676662234867</td><td>0.09824280618820228</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>1.1158806875176952</td><td>0.17023692798997558</td><td>4.127313378541158</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td
# %%
# Sampled no of each type of records
print(fraud_sample_df.count(), not_fraud_sample_df.count())
# Out:
# 60000 60000

# %%
# union of all samples
dataframe = fraud_sample_df.union(not_fraud_sample_df)
print(dataframe.count())
# Out:
# 120000

# %%
#casting all columns to float
from pyspark.sql.functions import col

cols = dataframe.columns
for col_name in cols:
    dataframe = dataframe.withColumn(col_name,col(col_name).cast('float'))

dataframe.printSchema()
# Out:
# root
#  |-- distance_from_home: float (nullable = true)
#  |-- distance_from_last_transaction: float (nullable = true)
#  |-- ratio_to_median_purchase_price: float (nullable = true)
#  |-- repeat_retailer: float (nullable = true)
#  |-- used_chip: float (nullable = true)
#  |-- used_pin_number: float (nullable = true)
#  |-- online_order: float (nullable = true)
#  |-- label: float (nullable = true)

# %%
# corelation between all columns
from pyspark.ml.stat import Correlation
from pyspark.ml.linalg import DenseMatrix, Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.sql.functions import *


assembler = VectorAssembler(inputCols=dataframe.columns, outputCol="features",handleInvalid='keep')
assembled_df = assembler.transform(dataframe).select("features")

correlation = Correlation.corr(assembled_df,"features","pearson").collect()

rows = correlation[0][0].toArray().tolist()
corr_df = spark.createDataFrame(rows,dataframe.columns)

corr_df.display()
"""
    Since all values are less than 0.8 and greater than -0.8, all columns are dependent on each other
"""
# Out:
# /databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distance_from_home</th><th>distance_from_last_transaction</th><th>ratio_to_median_purchase_price</th><th>repeat_retailer</th><th>used_chip</th><th>used_pin_number</th><th>online_order</th><th>label</th></tr></thead><tbody><tr><td>1.0</td><td>-0.014254847799086683</td><td>-0.07496887876034605</td><td>0.149379318464247</td><td>-0.09926993588692853</td><td>-0.03136855637513838</td><td>0.05364366582704245</td><td>0.20342372396078864</td></tr><tr><td>-0.014254847799086683</td><td>1.0</td><td>-0.03687081015751278</td><td>-0.017452895487788646</td><td>-0.03551287526230478</td><td>-0.015785347916851808</td><td>0.01959548723788795</td><td>0.11226537206784688</td></tr><tr><td>-0.07496887876034605</td><td>-0.03687081015751278</td><td>1.0</td><td>-0.0411269341399975</td><td>0.034560438131756945</td><td>-0.09166370578776015</td><td>0.14234331876785342</td><td>0.48781078931931415</td></tr><tr><td>0.149379318464247</td><td>-0.017452895487788646</td><td>-0.0411269341399975</td><td>1.0</td><td>-0.004931687386543046</td><td>4.0971342126013585E-4</td><td>0.07349551410551443</td><td>-0.004192091760619858</td></tr><tr><td>-0.09926993588692853</td><td>-0.03551287526230478</td><td>0.034560438131756945</td><td>-0.004931687386543046</td><td>1.0</td><td>0.0188952454790714</td><td>-0.025420017021263126</td><td>-0.11223575672889773</td></tr><tr><td>-0.03136855637513838</td><td>-0.015785347916851808</td><td>-0.09166370578776015</td><td>4.0971342126013585E-4</td><td>0.0188952454790714</td><td>1.0</td><td>-0.07487040978365098</td><td>-0.23339136724267553</td></tr><tr><td>0.05364366582704245</td><td>0.01959548723788795</td><td>0.14234331876785342</td><td>0.07349551410551443</td><td>-0.025420017021263126</td><td>-0.07487040978365098</td><td>1.0</td><td>0.39323728491356674</td></tr><tr><td>0.20342372396078864</td><td>0.11226537206784688</td><td>0.48781078931931415</td><td>-0.004192091760619858</td><td>-0.11223575672889773</td><td>-0.23339136724267553</td><td>0.39323728491356674</td><td>1.0</td></tr></tbody></table></div>
# Out[16]: '\n    Since all values are less than 0.8 and greater than -0.8, all columns are dependent on each other\n'

# %%
train_df, test_df = dataframe.randomSplit(weights=[0.7,0.3], seed=2321)

# %%
print(train_df.count(), test_df.count())
# Out:
# 84054 35946

# %%
from pyspark.ml.feature import VectorAssembler

cols_without_label = train_df.columns
cols_without_label.remove("label")
assembled_train_df = VectorAssembler(inputCols=cols_without_label, outputCol="cols_vector",handleInvalid='keep').transform(train_df)
assembled_test_df = VectorAssembler(inputCols=cols_without_label, outputCol="cols_vector",handleInvalid='keep').transform(test_df)

# %%
from pyspark.ml.feature import MinMaxScaler

scaled_train_df = MinMaxScaler(inputCol="cols_vector",outputCol="cols_scaled").fit(assembled_train_df).transform(assembled_train_df)
scaled_test_df = MinMaxScaler(inputCol="cols_vector",outputCol="cols_scaled").fit(assembled_test_df).transform(assembled_test_df)

# %%
scaled_train_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distance_from_home</th><th>distance_from_last_transaction</th><th>ratio_to_median_purchase_price</th><th>repeat_retailer</th><th>used_chip</th><th>used_pin_number</th><th>online_order</th><th>label</th><th>cols_vector</th><th>cols_scaled</th></tr></thead><tbody><tr><td>0.08547844</td><td>0.060152363</td><td>6.157767</td><td>0.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.08547843992710114, 0.060152363032102585, 6.157766819000244, 0.0, 1.0, 0.0, 1.0))</td><td>Map(vectorType -> dense, length -> 7, values -> List(6.033889858216556E-6, 2.818296235331626E-5, 0.049392701388342855, 0.0, 1.0, 0.0, 1.0))</td></tr><tr><td>0.093916506</td><td>0.008813569</td><td>5.05939</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.09391650557518005, 0.008813569322228432, 5.059390068054199, 0.0, 0.0, 0.0, 1.0))</td><td>Map(vectorType -> dense, length -> 7, values -> List(6.827485446744144E-6, 3.965399330667166E-6, 0.04056364464066715, 0.0, 0.0, 0.0, 1.0))</td></tr><tr><td>0.10451535</td><td>6.9127526</td><td>6.984204</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(0.10451535135507584, 6.912752628326416, 6.984203815460205))</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(7.824301257998763E-6, 0.0032606951972847073, 0.056035831019263176))</td></tr><tr><td>0.12000077</td><td>0.02414789</td><td>12.3019</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.12000077217817307, 0.024147890508174896, 12.301899909973145, 0.0, 0.0, 0.0, 1.0))</td><td>Map(vectorType -> dense, length -> 7, values -> List(9.280696854364034E-6, 1.1198913460913994E-5, 0.09878094606736432, 0.0, 0.0, 0.0, 1.0))</td></tr><tr><td>0.121058896</td><td>1.4599624</td><td>4.263229</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.12105889618396759, 1.4599623680114746, 4.263228893280029, 0.0, 0.0, 0.0, 1.0))</td><td>Map(vectorType -> dense, length -> 7, values -> List(9.380212854610472E-6, 6.885020810084668E-4, 0.034163880455634246, 0.0, 0.0, 0.0, 1.0))</td></tr><tr><td>0.1287654</td><td>0.074746646</td><td>4.185111</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.12876540422439575, 0.07474664598703384, 4.185111045837402, 0.0, 0.0, 0.0, 1.0))</td><td>Map(vectorType -> dense, length -> 7, values -> List(1.0105005839034403E-5, 3.506738525637024E-5, 0.03353594754692767, 0.0, 0.0, 0.0, 1.0))</td></tr><tr><td>0.14182104</td><td>0.31494662</td><td>5.4253464</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(0.14182104170322418, 0.31494662165641785, 5.425346374511719))</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(1.1332881603543597E-5, 1.4837464529223027E-4, 0.043505302859580014))</td></tr><tr><td>0.14406335</td><td>20.260767</td><td>6.465733</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(0.14406335353851318, 20.260766983032227, 6.465733051300049))</td><td>Map(vectorType -> sparse, length -> 7, indices -> List(0, 1, 2), values -> List(1.1543769839639945E-5, 0.009557227614643391, 0.05186821931878057))</td></tr><tr><td>0.15148231</td><td>0.5478149</td><td>5.1589985</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>Map(vectorType -> dense, length -> 7, values -> List(0.15148231387138367, 0.5478149056434631, 5.158998489379883, 0.0, 0.0, 0.0, 1.0) ...

# %%
from pyspark.ml.classification import LinearSVC

lsvc = LinearSVC(featuresCol="cols_scaled", labelCol="label",maxIter=10000)
model = lsvc.fit(scaled_train_df)

# %%
predictions = model.transform(scaled_test_df)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from sklearn.metrics import confusion_matrix

evaluator=MulticlassClassificationEvaluator(metricName="accuracy")
acc = evaluator.evaluate(predictions)
 
print("Prediction Accuracy: ", acc)

y_pred=predictions.select("prediction").collect()
y_orig=predictions.select("label").collect()

cm = confusion_matrix(y_orig, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Prediction Accuracy:  0.8928114393812941
# Confusion Matrix:
# [[14260  3703]
#  [  150 17833]]
